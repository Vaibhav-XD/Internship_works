# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen as uReq
import re

# %%
url = " https://yoshops.com"
headers = {"User-Agent": "Mozilla/5.0"}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Yoshops.com | India's Online Store For Toys And  Electronics Item</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1" name="viewport"/>
# <meta content="Yoshops.com is online store offer Mobiles,Headphone,Bluetooth Headphone,Sony PlayStation,Earphone,Bags, FMCG Product,Led Tv,Mobile Accessories,Laptop Accesories, FREE SHIPPING,Cash On Delivery,Food,Free Internship,Online Live Classes,Training,RC Toys" name="description"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="zbIhEHYRHecRi3bBFx2wtUeyro4CbptMf858k87sPnx5JuwmBJ4rvfY5qHkhejlxC0AklOW5TJi/ZQ5uKz1CZg==" name="csrf-token"/>
# ...

# %%
categories = soup.find_all('li',class_='dropdown')[1:]

# %%
categories
# Out:
# [<li class="dropdown">
#  <a href="/t/toys">Toys &amp; Games <span class="caret"></span></a>
#  <ul class="dropdown-menu">
#  <li>
#  <a href="/t/playstation">PlayStation</a>
#  </li>
#  <li>
#  <a href="/t/drones">Drones</a>
#  </li>
#  <li>
#  <a href="/t/rc-helicopter">RC Toys</a>
#  </li>
#  <li>
#  <a href="/t/soft-toys">Soft Toys</a>
#  </li>
#  <li>
#  <a href="/t/gaming-accessories">Gaming Accessories</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="dropdown">
#  <a href="/t/mobile-phones">Mobiles <span class="caret"></span></a>
#  <ul class="dropdown-menu">
#  <li>
#  <a href="/t/smartphones">Smartphones</a>
#  </li>
#  <li>
#  <a href="/t/headphones">Headphones</a>
#  </li>
#  <li>
#  <a href="/t/mobiles-accessories">Mobiles Accessories</a>
#  </li>
#  <li>
#  <a href="/t/basic-keypad-phone">Feature Keypad Mobiles</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="dropdown">
#  <a href="/t/laptops">Laptops <span class="caret"></span></a>
#  <ul class="dropdown-menu">
#  <li>
# ...

# %%
from collections import Counter

# %%
data = []

for category in categories:
  category_name = category.find('a').text.strip()
  sub_category = category.find_all('ul',class_='dropdown-menu')
  print(f"category: {category_name}")
  
  for subcategory in sub_category:
    sub_cat_name = subcategory.find_all('li')
    
    for name in sub_cat_name:
      print(f"\tsubcategories:{name.text.strip()}")
      data.append({'category': category_name,'subcategory':name.text.strip()})
df = pd.DataFrame(data)
# Out:
# category: Toys & Games
# 	subcategories:PlayStation
# 	subcategories:Drones
# 	subcategories:RC Toys
# 	subcategories:Soft Toys
# 	subcategories:Gaming Accessories
# category: Mobiles
# 	subcategories:Smartphones
# 	subcategories:Headphones
# 	subcategories:Mobiles Accessories
# 	subcategories:Feature Keypad Mobiles
# category: Laptops
# 	subcategories:Gaming Laptops
# 	subcategories:Personal Laptops
# 	subcategories:Tablets
# 	subcategories:Laptop Accessories
# 	subcategories:Computers Accessories
# category: Accessories
# 	subcategories:Books
# 	subcategories:Stationery
# 	subcategories:Bags
# 	subcategories:SpareParts
#
#
# Auto spare parts
#
#
# Mobile Spare Parts
#
#
# Laptop spare parts
# 	subcategories:Auto spare parts
# 	subcategories:Mobile Spare Parts
# 	subcategories:Laptop spare parts
# 	subcategories:More
# category: Electronics
# 	subcategories:Led TV
# 	subcategories:Others
# category: Home & Kitchen
# 	subcategories:Irons
# 	subcategories:Mixer Grinder Juicer
# ...

# %%
website = input('Enter the website')
category = input('Enter the category/sub_category')

# %%
# choose the categories from = toys , mobile-phones , laptops , accessories , electronics ,
# home--kitchen , fashion , food , Services
url = 'https://yoshops.com/t/'+category.lower()
url
# Out:
# 'https://yoshops.com/t/toys'

# %%
response = requests.get(url, headers=headers)
response.status_code
print(response)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
table = soup.find('ul', attrs={'id':'page-cat-list'})
ch=table.find_all('li')
ch
# Out:
# [<li class="active">
#  <a href="/t/toys">Toys &amp; Games</a>
#  <ul>
#  <li>
#  <a href="/t/playstation">PlayStation</a>
#  </li>
#  <li>
#  <a href="/t/drones">Drones</a>
#  </li>
#  <li>
#  <a href="/t/rc-helicopter">RC Toys</a>
#  </li>
#  <li>
#  <a href="/t/soft-toys">Soft Toys</a>
#  </li>
#  <li>
#  <a href="/t/gaming-accessories">Gaming Accessories</a>
#  </li>
#  </ul>
#  </li>,
#  <li>
#  <a href="/t/playstation">PlayStation</a>
#  </li>,
#  <li>
#  <a href="/t/drones">Drones</a>
#  </li>,
#  <li>
#  <a href="/t/rc-helicopter">RC Toys</a>
#  </li>,
#  <li>
#  <a href="/t/soft-toys">Soft Toys</a>
#  </li>,
#  <li>
#  <a href="/t/gaming-accessories">Gaming Accessories</a>
#  </li>,
#  <li>
#  <a href="/t/mobile-phones">Mobiles</a>
#  <ul>
#  <li>
#  <a href="/t/smartphones">Smartphones</a>
#  </li>
#  <li>
#  <a href="/t/headphones">Headphones</a>
#  </li>
#  <li>
#  <a href="/t/mobiles-accessories">Mobiles Accessories</a>
#  </li>
#  <li>
# ...

# %%
cat = []
subcategory = []
link1 = []

# %%
y = ch[0].find('a',href=True)
x=y.text.strip()
#print(x)
cat1 = [x]*len(range(1,6))
cat = cat+cat1
print(cat1)
# Out:
# ['Toys & Games', 'Toys & Games', 'Toys & Games', 'Toys & Games', 'Toys & Games']

# %% [markdown]
# Toys and Games

# %%
for i in range(1,6):
    y = ch[i].find('a',href=True)
    x1=y['href']
    print(x1)
    link1.append(x1)
    x=y.text.strip()
    subcategory.append(x)
# Out:
# /t/playstation
# /t/drones
# /t/rc-helicopter
# /t/soft-toys
# /t/gaming-accessories

# %%
ch[6]
# Out:
# <li>
# <a href="/t/mobile-phones">Mobiles</a>
# <ul>
# <li>
# <a href="/t/smartphones">Smartphones</a>
# </li>
# <li>
# <a href="/t/headphones">Headphones</a>
# </li>
# <li>
# <a href="/t/mobiles-accessories">Mobiles Accessories</a>
# </li>
# <li>
# <a href="/t/basic-keypad-phone">Feature Keypad Mobiles</a>
# </li>
# </ul>
# </li>

# %% [markdown]
# Mobile Category

# %%
y = ch[6].find('a',href=True)
x=y.text.strip()
#print(x)
cat1 = [x]*len(range(7,11))
cat = cat+cat1
print(cat1)
# Out:
# ['Mobiles', 'Mobiles', 'Mobiles', 'Mobiles']

# %%
for i in range(7,11):
    y = ch[i].find('a',href=True)
    x1=y['href']
    print(x1)
    link1.append(x1)
    x=y.text.strip()
    subcategory.append(x)
# Out:
# /t/smartphones
# /t/headphones
# /t/mobiles-accessories
# /t/basic-keypad-phone

# %% [markdown]
# laptop

# %%
y = ch[11].find('a',href=True)
x=y.text.strip()
#print(x)
cat1 = [x]*len(range(12,17))
cat = cat+cat1
print(cat1)
# Out:
# ['Laptops', 'Laptops', 'Laptops', 'Laptops', 'Laptops']

# %%
for i in range(12,17):
    y = ch[i].find('a',href=True)
    x1=y['href']
    print(x1)
    link1.append(x1)
    x=y.text.strip()
    subcategory.append(x)
# Out:
# /t/gaming-laptops
# /t/personal-laptops
# /t/tablets
# /t/laptop-accessories
# /t/computers-accessories

# %% [markdown]
# Accessories

# %%
y = ch[17].find('a',href=True)
x=y.text.strip()
#print(x)
cat1 = [x]*len(range(18,26))
cat = cat+cat1
print(cat1)
# Out:
# ['Accessories', 'Accessories', 'Accessories', 'Accessories', 'Accessories', 'Accessories', 'Accessories', 'Accessories']

# %%
for i in range(18,26):
    y = ch[i].find('a',href=True)
    x1=y['href']
    print(x1)
    link1.append(x1)
    x=y.text.strip()
    subcategory.append(x)
# Out:
# /t/books
# /t/stationery
# /t/books--bags
# /t/grocery
# /t/bike
# /t/Mobile-Parts
# /t/Laptop-spare-parts
# /t/more

# %% [markdown]
# Electronics

# %%
y = ch[26].find('a',href=True)
x=y.text.strip()
#print(x)
cat1 = [x]*len(range(27,29))
cat = cat+cat1
print(cat1)
# Out:
# ['Electronics', 'Electronics']

# %%
for i in range(27,29):
    y = ch[i].find('a',href=True)
    x1=y['href']
    print(x1)
    link1.append(x1)
    x=y.text.strip()
    subcategory.append(x)
# Out:
# /t/led-tv
# /t/jewelry--watches

# %% [markdown]
# Home & Kitchen

# %%
y = ch[29].find('a',href=True)
x=y.text.strip()
#print(x)
cat1 = [x]*len(range(30,32))
cat = cat+cat1
print(cat1)
# Out:
# ['Home & Kitchen', 'Home & Kitchen']

# %%
for i in range(30,32):
    y = ch[i].find('a',href=True)
    x1=y['href']
    print(x1)
    link1.append(x1)
    x=y.text.strip()
    subcategory.append(x)
# Out:
# /t/irons
# /t/mixer-grinder-juicer

# %% [markdown]
# Fashion

# %%
y = ch[32].find('a',href=True)
x=y.text.strip()
#print(x)
cat1 = [x]*len(range(33,45))
cat = cat+cat1
print(cat1)
# Out:
# ['Fashion', 'Fashion', 'Fashion', 'Fashion', 'Fashion', 'Fashion', 'Fashion', 'Fashion', 'Fashion', 'Fashion', 'Fashion', 'Fashion']

# %%
for i in range(33,45):
  y=ch[i].find('a', href=True)
  x1=y['href']
  print(x1)
  link1.append(x1)
  x=y.text.strip()
  subcategory.append(x)
# Out:
# /t/men
# /t/men-clothing
# /t/sunglasses
# /t/watches
# /t/mens-footwear
# /t/womens
# /t/women-clothing
# /t/face-makeup
# /t/personal-care
# /t/kids
# /t/kids-clothing
# /t/shoes

# %% [markdown]
# Foods

# %%
y=ch[45].find('a', href=True)
x=y.text.strip()
#print(x)
cat1 = [x]*len(range(46,51))
cat=cat+cat1
print(cat1)
# Out:
# ['Foods', 'Foods', 'Foods', 'Foods', 'Foods']

# %%
for i in range(46,51):
  y=ch[i].find('a', href=True)
  x1=y['href']
  print(x1)
  link1.append(x1)
  x=y.text.strip()
  subcategory.append(x)
# Out:
# /t/organic
# /t/vegetable
# /t/non-veg
# /t/seafood
# /t/biryani

# %% [markdown]
# Services

# %%
y=ch[51].find('a', href=True)
x=y.text.strip()
#print(x)
cat1 = [x]*len(range(52,64))
cat=cat+cat1
print(cat1)
# Out:
# ['Services', 'Services', 'Services', 'Services', 'Services', 'Services', 'Services', 'Services', 'Services', 'Services', 'Services', 'Services']

# %%
for i in range(52,64):
  y=ch[i].find('a', href=True)
  x1=y['href']
  print(x1)
  link1.append(x1)
  x=y.text.strip()
  subcategory.append(x)
# Out:
# /t/tuition
# /t/internship
# /t/pcd-pharma-distributor
# /t/sponsorship-marketing
# /t/teacher-sponsorship
# /t/blog-sponsorship
# /t/instagram-sponsorship
# /t/youtuber-sponsorship
# /t/refurbished-and-used-laptop-phone
# /t/bengaluru
# /t/chennai
# /t/mumbai

# %%
print(subcategory)
print(link1)
# Out:
# ['PlayStation', 'Drones', 'RC Toys', 'Soft Toys', 'Gaming Accessories', 'Smartphones', 'Headphones', 'Mobiles Accessories', 'Feature Keypad Mobiles', 'Gaming Laptops', 'Personal Laptops', 'Tablets', 'Laptop Accessories', 'Computers Accessories', 'Books', 'Stationery', 'Bags', 'SpareParts', 'Auto spare parts', 'Mobile Spare Parts', 'Laptop spare parts', 'More', 'Led TV', 'Others', 'Irons', 'Mixer Grinder Juicer', 'Men', 'Men Clothing', 'Sunglasses', 'Watches', "Men's Footwear", 'Womens', 'Women Clothing', 'Face Makeup', 'Personal Care', 'Kids', 'Kids Clothing', 'Shoes', 'Organic foods', 'Vegetable', 'Non Veg', 'Seafood', 'Biryani', 'Online Live Tuition', 'Training Internship Work From Home', 'Yoga Pharma Franchise', 'Sponsorship Marketing', 'Teacher Sponsorship', 'Blog Sponsorship', 'Instagram Sponsorship', 'YouTube Sponsorship', 'Refurbish Laptop Mobiles', 'Bengaluru', 'Chennai', 'Mumbai']
# ...

# %%
# %pip install autoscraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\vaibhav\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from autoscraper import AutoScraper

# %%
url1 = []
for link2 in link1:
    x="https://yoshops.com/"+link2
    url1.append(x)
    i=i+1
    
x = []
for i in range(len(url1)):
    wanted_list=['Sony PlayStation PS2 Gaming Console 150 GB Hard Disk With 50 Games Preloaded(Black)']
    scrapper = AutoScraper()
    result = scrapper.build(url1[0],wanted_list)
    mobile = scrapper.get_result_similar(url1[i],grouped=True)
    mobile_list = pd.DataFrame(mobile)
    x.append(len(mobile_list))

# %%
df = pd.DataFrame({'category':cat,'Subcategory':subcategory,'Number_of_product':x})

# %%
df.to_excel('Category_data_Yoshops.xlsx', index=True)

# %%
df
# Out:
#           category                         Subcategory  Number_of_product
# 0     Toys & Games                         PlayStation                  7
# 1     Toys & Games                              Drones                 19
# 2     Toys & Games                             RC Toys                 13
# 3     Toys & Games                           Soft Toys                 32
# 4     Toys & Games                  Gaming Accessories                 48
# 5          Mobiles                         Smartphones                  5
# 6          Mobiles                          Headphones                 48
# 7          Mobiles                 Mobiles Accessories                 48
# 8          Mobiles              Feature Keypad Mobiles                  9
# 9          Laptops                      Gaming Laptops                  5
# 10         Laptops                    Personal Laptops                  5
# 11         Laptops                             Tablets                  6
# ...
